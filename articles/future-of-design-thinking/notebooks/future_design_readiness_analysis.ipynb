# %% [markdown]
# # The Future of Design Thinking
#
# Professional future design-readiness analysis notebook.

# %%
from pathlib import Path
import pandas as pd

article_dir = Path('..')
initiatives = pd.read_csv(article_dir / 'data' / 'raw' / 'future_design_initiatives_raw.csv')
initiatives.head()
