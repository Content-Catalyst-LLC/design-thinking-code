# %% [markdown]
# # Design Thinking and Behavioral Design
# Exploratory notebook scaffold for behavioral-design analysis.

# %%
from pathlib import Path
import pandas as pd
article_dir = Path('..')
pd.read_csv(article_dir / 'data/raw/behavioral_interventions_raw.csv').head()
